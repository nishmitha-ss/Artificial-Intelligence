# %% [markdown]
# $ Loss = {1 \over 2}{(y_1 - \hat{y_1})^2} $
# <br><br><br>
# $For {{\partial L}\over{\partial b^2}}:$
#     <br><br>
# $
# {{\partial L}\over{\partial b^2}}=
# {{\partial L}\over{\partial \hat y_1}}.
# {{\partial \hat y_1}\over{\partial h^2_1}}.
# {{\partial  h^2_1}\over{\partial a^2_1}}.
# {{\partial  a^2_1}\over{\partial b^2}}
# ={{\partial L}\over{\partial h^2_1}}.{{\partial  h^2_1}\over{\partial a^2_1}}.{{\partial  a^2_1}\over{\partial b^2}}$
# <br>
# ${{\partial L}\over{\partial h^2_1}}={(\hat{y_1}- y_1)}$
# <br>
# ${{\partial  h^2_1}\over{\partial a^2_1}}={\hat{y_1}(1- \hat{y_1})}$
# <br>
# ${{\partial  a^2_1}\over{\partial b^2}}=1$
# $${{\partial L}\over{\partial b^2}}={(\hat{y_1}- y_1)}.{\hat{y_1}(1- \hat{y_1})}$$<br>
# $${b^2}={b^2}-\sum {{\partial L}\over{\partial b^2}}$$
# <br><br><br><br><br><br><br>
# $For {{\partial L}\over{\partial \vec{b^1}}}:$
# <br>
# $${{\partial L}\over{\partial \vec{b^1}}}=
# \begin{bmatrix}{{\partial L}\over{\partial b^1_1}}  \\{{\partial L}\over{\partial b^1_2}}  \end{bmatrix}$$
# <br>
# $
# {{\partial L}\over{\partial b^1_1}}=
# {{\partial L}\over{\partial h^1_1}}.
# {{\partial h^1_1}\over{\partial a^1_1}}.
# {{\partial  a^1_1}\over{\partial b^1_1}}$
# <br>
# ${{\partial L}\over{\partial h^1_1}}={{\partial L}\over{\partial h^2_1}}.{{\partial  h^2_1}\over{\partial a^2_1}}.
# {{\partial  a^2_1}\over{\partial h^1_1}}={(\hat{y_1}- y_1)}.{\hat{y_1}(1- \hat{y_1})}.w^2_{11}$
# <br>
# ${{\partial h^1_1}\over{\partial a^1_1}}={(1-{(h^1_1)}^2)}$
# <br>
# ${{\partial  a^1_1}\over{\partial b^1_1}}=1$
# <br>
# $${{\partial L}\over{\partial b^1_1}}={(\hat{y_1}- y_1)}.{\hat{y_1}(1- \hat{y_1})}.w^2_{11}.{(1-{(h^1_1)}^2)}$$
# <br>
# $${b^1_1}={b^1_1}-\sum {{\partial L}\over{\partial b^1_1}}$$
# $
# {{\partial L}\over{\partial b^1_2}}=
# {{\partial L}\over{\partial h^1_2}}.
# {{\partial h^1_2}\over{\partial a^1_2}}.
# {{\partial  a^1_2}\over{\partial b^1_2}}$
# <br>
# ${{\partial L}\over{\partial h^1_2}}={{\partial L}\over{\partial h^2_1}}.{{\partial  h^2_1}\over{\partial a^2_1}}.
# {{\partial  a^2_1}\over{\partial h^1_2}}={(\hat{y_1}- y_1)}.{\hat{y_1}(1- \hat{y_1})}.w^2_{21}$
# <br>
# ${{\partial h^1_2}\over{\partial a^1_2}}={(1-{(h^1_2)}^2)}$
# <br>
# ${{\partial  a^1_2}\over{\partial b^1_2}}=1$
# <br>
# $${{\partial L}\over{\partial b^1_2}}={(\hat{y_1}- y_1)}.{\hat{y_1}(1- \hat{y_1})}.w^2_{21}.{(1-{(h^1_2)}^2)}$$<br>
# $${b^1_2}={b^1_2}-\sum {{\partial L}\over{\partial b^1_2}}$$
# <br><br><br><br><br><br><br>
# $For {{\partial L}\over{\partial \vec{W^2}}}:$
# <br>
# $${{\partial L}\over{\partial \vec{W^2}}}=
# \begin{bmatrix}{{\partial L}\over{\partial w^2_{11}} } \\{{\partial L}\over{\partial w^2_{21}} } \end{bmatrix}$$
# <br>
# $
# {{\partial L}\over{\partial w^2_{11}}}=
# {{\partial L}\over{\partial h^2_1}}.
# {{\partial h^2_1}\over{\partial a^2_1}}.
# {{\partial  a^2_1}\over{\partial w^2_{11}}}$
# <br>
# ${{\partial L}\over{\partial h^2_1}}={(\hat{y_1}- y_1)}$
# <br>
# ${{\partial  h^2_1}\over{\partial a^2_1}}={\hat{y_1}(1- \hat{y_1})}$
# <br>
# ${{\partial  a^2_1}\over{\partial w^2_{11}}}={h^1_1}$
# $${{\partial L}\over{\partial w^2_{11}}}={(\hat{y_1}- y_1)}.{\hat{y_1}(1- \hat{y_1})}.{h^1_1}$$
# <br>
# $${w^2_{11}}={w^2_{11}}-\sum {{\partial L}\over{\partial w^2_{11}}}$$
# $
# {{\partial L}\over{\partial w^2_{21}}}=
# {{\partial L}\over{\partial h^2_1}}.
# {{\partial h^2_1}\over{\partial a^2_1}}.
# {{\partial  a^2_1}\over{\partial w^2_{21}}}$
# <br>
# ${{\partial L}\over{\partial h^2_1}}={(\hat{y_1}- y_1)}$
# <br>
# ${{\partial  h^2_1}\over{\partial a^2_1}}={\hat{y_1}(1- \hat{y_1})}$
# <br>
# ${{\partial  a^2_1}\over{\partial w^2_{21}}}={h^1_2}$
# $${{\partial L}\over{\partial w^2_{21}}}={(\hat{y_1}- y_1)}.{\hat{y_1}(1- \hat{y_1})}.{h^1_2}$$
# <br>
# $${w^2_{21}}={w^2_{21}}-\sum {{\partial L}\over{\partial w^2_{21}}}$$
# <br><br><br><br><br><br><br>
# $For {{\partial L}\over{\partial \vec{W^1}}}:$
#     <br>
#     $${{\partial L}\over{\partial \vec{W^1}}}=
# \begin{bmatrix}{{\partial L}\over{\partial w^1_{11}}} &{{\partial L}\over{\partial w^1_{12}}}\\
# {{\partial L}\over{\partial w^1_{21}}}&{{\partial L}\over{\partial w^1_{22}}} \end{bmatrix}$$
# <br><br>
# ${{\partial L}\over{\partial w^1_{11}}}=
# {{\partial L}\over{\partial h^1_1}}.
# {{\partial h^1_1}\over{\partial a^1_1}}.
# {{\partial  a^1_1}\over{\partial w^1_{11}}}$
# <br>
# ${{\partial L}\over{\partial h^1_1}}={(\hat{y_1}- y_1)}.{\hat{y_1}(1- \hat{y_1})}.w^2_{11}$
# <br>
# ${{\partial h^1_1}\over{\partial a^1_1}}={(1-{(h^1_1)}^2)}$
# <br>
# ${{\partial  a^1_1}\over{\partial w^1_{11}}}={x_1}$
# <br>
# $${{\partial L}\over{\partial w^1_{11}}}={(\hat{y_1}- y_1)}.{\hat{y_1}(1- \hat{y_1})}.w^2_{11}.{(1-{(h^1_1)}^2)}.{x_1}
# $$<br>
# $${w^1_{11}}={w^1_{11}}-\sum {{\partial L}\over{\partial w^1_{11}}}$$
# ${{\partial L}\over{\partial w^1_{12}}}=
# {{\partial L}\over{\partial h^1_2}}.
# {{\partial h^1_2}\over{\partial a^1_2}}.
# {{\partial  a^1_2}\over{\partial w^1_{12}}}$
# <br>
# ${{\partial L}\over{\partial h^1_2}}={(\hat{y_1}- y_1)}.{\hat{y_1}(1- \hat{y_1})}.w^2_{21}$
# <br>
# ${{\partial h^1_2}\over{\partial a^1_2}}={(1-{(h^1_2)}^2)}$
# <br>
# ${{\partial  a^1_2}\over{\partial w^1_{12}}}={x_1}$
# <br>
# $${{\partial L}\over{\partial w^1_{12}}}={(\hat{y_1}- y_1)}.{\hat{y_1}(1- \hat{y_1})}.w^2_{21}.{(1-{(h^1_2)}^2)}.{x_1}
# $$<br>
# $${w^1_{12}}={w^1_{12}}-\sum {{\partial L}\over{\partial w^1_{12}}}$$
# ${{\partial L}\over{\partial w^1_{21}}}=
# {{\partial L}\over{\partial h^1_1}}.
# {{\partial h^1_1}\over{\partial a^1_1}}.
# {{\partial  a^1_1}\over{\partial w^1_{21}}}$
# <br>
# ${{\partial L}\over{\partial h^1_1}}={(\hat{y_1}- y_1)}.{\hat{y_1}(1- \hat{y_1})}.w^2_{11}$
# <br>
# ${{\partial h^1_1}\over{\partial a^1_1}}={(1-{(h^1_1)}^2)}$
# <br>
# ${{\partial  a^1_1}\over{\partial w^1_{21}}}={x_2}$
# <br>
# $${{\partial L}\over{\partial w^1_{21}}}={(\hat{y_1}- y_1)}.{\hat{y_1}(1- \hat{y_1})}.w^2_{11}.{(1-{(h^1_1)}^2)}.{x_2}
# $$<br>
# $${w^1_{21}}={w^1_{21}}-\sum {{\partial L}\over{\partial w^1_{21}}}$$
# ${{\partial L}\over{\partial w^1_{22}}}=
# {{\partial L}\over{\partial h^1_2}}.
# {{\partial h^1_2}\over{\partial a^1_2}}.
# {{\partial  a^1_2}\over{\partial w^1_{22}}}$
# <br>
# ${{\partial L}\over{\partial h^1_2}}={(\hat{y_1}- y_1)}.{\hat{y_1}(1- \hat{y_1})}.w^2_{21}$
# <br>
# ${{\partial h^1_2}\over{\partial a^1_2}}={(1-{(h^1_2)}^2)}$
# <br>
# ${{\partial  a^1_2}\over{\partial w^1_{22}}}={x_2}$
# <br>
# $${{\partial L}\over{\partial w^1_{22}}}={(\hat{y_1}- y_1)}.{\hat{y_1}(1- \hat{y_1})}.w^2_{21}.{(1-{(h^1_2)}^2)}.{x_2}
# $$<br>
# $${w^1_{22}}={w^1_{22}}-\sum {{\partial L}\over{\partial w^1_{22}}}$$
# <br><br>

# %%
import numpy as np
X=np.array([[0,0],[0,1],[1,0],[1,1]])
x=X.T
y=np.array([[0,1,1,0]])
m = x.shape[1]

def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def tanh(z):
    return (np.exp(z) - np.exp(-z))/(np.exp(z) + np.exp(-z))
def derv_tanh(z):
    return (1 + tanh(z)) * (1 - tanh(z))

no_x = 2
no_y = 1
no_h = 2
lr = 0.1
np.random.seed(2)
w1 = np.random.rand(no_h,no_x)   
w2 = np.random.rand(no_y,no_h)
b1 = np.random.rand(no_h, 1)
b2 = np.random.rand(no_y, 1)
    
def forwardProp(w1,b1,w2,b2,x):
    a1 = np.dot(w1,x)+b1
    h1 = tanh(a1)    
    a2 = np.dot(w2,h1)+b2
    h2 = sigmoid(a2)
    return a1,h1,a2,h2

def backProp(m,w1,w2,a1,h1,a2,h2,b1,b2,y):
    da2 = h2-y 
    dw2 = np.dot(da2,h1.T)/m
    db2 = np.sum(da2,1)/m
    da1 = np.dot(w2.T,da2) * derv_tanh(a1)
    dw1 = np.dot(da1,x.T)/m
    db1 = np.sum(da1,1)/m 
    b1 = b1 - lr * db1
    b2 = b2 - lr * db2
    return db2,dw2,db1,dw1
 
iterations = 10000
for i in range(iterations):
    a1,h1,a2,h2 = forwardProp(w1,b1,w2,b2,x)
    dh2,dw2,da1,dw1 = backProp(m,w1,w2,a1,h1,a2,h2,b1,b2,y)
    w2 = w2 - lr * dw2
    w1 = w1 - lr * dw1
    
def predict(w1,w2,input):
    a1,h1,a2,h2 = forwardProp(w1,b1,w2,b2,test)
    h2 = np.squeeze(h2)
    if h2>=0.5:
        print("For input", [i[0] for i in input], "output is 1")
    else:
        print("For input", [i[0] for i in input], "output is 0")

# %%
test = np.array([[0],[0]])
predict(w1,w2,test)
test = np.array([[0],[1]])
predict(w1,w2,test) 
test = np.array([[1],[0]])
predict(w1,w2,test)
test = np.array([[1],[1]])
predict(w1,w2,test)
# Out:
# For input [0, 0] output is 0
# For input [0, 1] output is 1
# For input [1, 0] output is 1
# For input [1, 1] output is 0
